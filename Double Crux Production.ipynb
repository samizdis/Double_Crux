# %%
import pandas as pd

# %%
csv_filename = 'Double Crux Questionnaire (Responses) - Form responses (anon).csv'

# %%
pd.read_csv(csv_filename, index_col='Name')
# Out:
#                    Timestamp  \
# Name
# Adam     23/07/2022 20:42:09
# Betty    23/07/2022 20:53:38
# Charlie  23/07/2022 20:53:41
# David    23/07/2022 20:53:52
# Eve      23/07/2022 20:54:09
# Felix    23/07/2022 20:54:16
# Grace    23/07/2022 20:54:17
# Harley   23/07/2022 20:54:34
# Ian      23/07/2022 20:54:45
# Jade     23/07/2022 20:54:46
# Kelly    23/07/2022 20:54:47
# Leo      23/07/2022 20:54:51
# Mia      23/07/2022 20:54:53
# Noah     23/07/2022 20:54:58
# Olivia   23/07/2022 20:55:24
# Parker   23/07/2022 20:55:32
# Quin     23/07/2022 20:55:37
# Ryan     23/07/2022 20:55:58
# Sydney   23/07/2022 20:56:47
#
#          "If my country asked me to fight a war, I would."  \
# Name
# Adam                                                     4
# Betty                                                    2
# Charlie                                                  5
# David                                                    5
# Eve                                                      5
# Felix                                                    3
# Grace                                                    5
# Harley                                                   6
# Ian                                                      1
# Jade                                                     3
# Kelly                                                    3
# Leo                                                      2
# Mia                                                      3
# Noah                                                     4
# Olivia                                                   2
# Parker                                                   2
# Quin                                                     4
# Ryan                                                     2
# Sydney                                                   6
#
#          "It's sometimes necessary to censor books."  \
# Name
# Adam                                               1
# Betty                                              2
# Charlie                                            2
# David                                              5
# Eve                                                2
# Felix                                              5
# Grace                                              3
# Harley                                             7
# Ian                                                1
# Jade                                               5
# Kelly                                              2
# Leo                                                1
# Mia                                                6
# Noah                                               1
# Olivia                                             2
# Parker                                             2
# Quin                                               3
# Ryan                                               3
# Sydney                                             2
#
#          "It's OK to burn a country's flag."  \
# Name
# Adam                                       4
# Betty                                      7
# Charlie                                    7
# David                                      7
# Eve                                        7
# Felix                                      7
# Grace                                      6
# Harley                                     6
# Ian                                        7
# Jade                                       6
# Kelly                                      5
# Leo                                        7
# Mia                                        7
# Noah                                       4
# Olivia                                     2
# Parker                                     5
# Quin                                       7
# Ryan                                       6
# Sydney                                     7
#
#          "While swimming with an old friend and a new, promising friend, they both start to struggle. If I can pick only save one I should pick the old friend."  \
# Name
# Adam                                                     5
# Betty                                                    6
# Charlie                                                  5
# David                                                    5
# Eve                                                      5
# Felix                                                    5
# Grace                                                    6
# Harley                                                   4
# Ian                                                      4
# Jade                                                     7
# Kelly                                                    7
# Leo                                                      1
# Mia                                                      1
# Noah                                                     6
# Olivia                                                   4
# Parker                                                   5
# Quin                                                     4
# Ryan                                                     4
# Sydney                                                   6
#
#          "Someone employs ten people in a struggling business. They should fire their employees rather than commit tax fraud."  \
# Name
# Adam                                                     4
# Betty                                                    4
# Charlie                                                  6
# David                                                    7
# Eve                                                      6
# Felix                                                    5
# Grace                                                    6
# Harley                                                   7
# Ian                                                      2
# Jade                                                     6
# Kelly                                                    6
# Leo                                                      4
# Mia                                                      4
# Noah                                                     4
# Olivia                                                   6
# Parker                                                   6
# Quin                                                     2
# Ryan                                                     5
# Sydney                                                   6
#
#          "If my family member committed a crime, I would lie to cover for them."  \
# Name
# Adam                                                     7
# Betty                                                    5
# Charlie                                                  3
# David                                                    5
# Eve                                                      5
# Felix                                                    2
# Grace                                                    6
# Harley                                                   5
# Ian                                                      5
# Jade                                                     6
# Kelly                                                    4
# Leo                                                      2
# Mia                                                      4
# Noah                                                     6
# Olivia                                                   2
# Parker                                                   3
# Quin                                                     5
# Ryan                                                     2
# Sydney                                                   5
#
#          "Monogamous relationships are better than polyamorous ones."  \
# Name
# Adam                                                     7
# Betty                                                    5
# Charlie                                                  2
# David                                                    4
# Eve                                                      5
# Felix                                                    2
# Grace                                                    3
# Harley                                                   6
# Ian                                                      5
# Jade                                                     5
# Kelly                                                    2
# Leo                                                      2
# Mia                                                      4
# Noah                                                     4
# Olivia                                                   4
# Parker                                                   5
# Quin                                                     3
# Ryan                                                     3
# Sydney                                                   5
#
#          "I have a moral duty to avoid eating meat."  \
# Name
# Adam                                               4
# Betty                                              2
# Charlie                                            6
# David                                              2
# Eve                                                3
# Felix                                              5
# Grace                                              1
# Harley                                             5
# Ian                                                6
# Jade                                               6
# Kelly                                              1
# Leo                                                5
# Mia                                                4
# Noah                                               2
# Olivia                                             2
# Parker                                             5
# Quin                                               1
# Ryan                                               5
# Sydney                                             5
#
#          "It's worth people today working full-time to prevent AI causing human extinction."  \
# Name
# Adam                                                     7
# Betty                                                    7
# Charlie                                                  6
# David                                                    7
# Eve                                                      7
# Felix                                                    7
# Grace                                                    5
# Harley                                                   6
# Ian                                                      6
# Jade                                                     6
# Kelly                                                    6
# Leo                                                      6
# Mia                                                      7
# Noah                                                     7
# Olivia                                                   6
# Parker                                                   7
# Quin                                                     3
# Ryan                                                     7
# Sydney                                                   7
#
#          "Schools should be able to mandate uniforms."
# Name
# Adam                                                 5
# Betty                                                7
# Charlie                                              4
# David                                                4
# Eve                                                  4
# Felix                                                6
# Grace                                                6
# Harley                                               7
# Ian                                                  7
# Jade                                                 5
# Kelly                                                6
# Leo                                                  2
# Mia                                                  1
# Noah                                                 7
# Olivia                                               7
# Parker                                               5
# Quin                                                 6
# Ryan                                                 5
# Sydney                                               6

# %%
def biggest_difference(row1, row2):
    return (row1-row2).abs().max()

# %%
def build_distance_matrix(response_df, metric=biggest_difference):

    distance_matrix = pd.DataFrame(index=response_df.index,
                                   columns=response_df.index)

    for idx, row in response_df.iterrows():
        for idy, col in response_df.iterrows():        
            distance_matrix.loc[idx, idy] = metric(row, col)

    return distance_matrix

# %%
dm = build_distance_matrix(
        pd.read_csv(csv_filename, index_col='Name'
               ).drop('Timestamp', axis='columns'
                     )
).apply(pd.to_numeric)
dm
# Out:
# Name     Adam  Betty  Charlie  David  Eve  Felix  Grace  Harley  Ian  Jade  \
# Name
# Adam        0      3        5      4    3      5      4       6    3     4
# Betty       3      0        4      3    3      3      3       5    4     4
# Charlie     5      4        0      4    3      3      5       5    4     3
# David       4      3        4      0    3      3      2       3    5     4
# Eve         3      3        3      3    0      3      2       5    4     3
# Felix       5      3        3      3    3      0      4       4    4     4
# Grace       4      3        5      2    2      4      0       4    5     5
# Harley      6      5        5      3    5      4      4       0    6     3
# Ian         3      4        4      5    4      4      5       6    0     4
# Jade        4      4        3      4    3      4      5       3    4     0
# Kelly       5      3        5      3    3      4      2       5    5     5
# Leo         5      5        4      4    4      4      5       6    5     6
# Mia         5      6        4      4    4      5      5       6    6     6
# Noah        3      3        4      4    3      4      2       6    4     4
# Olivia      5      5        5      5    5      5      4       5    5     4
# Parker      4      3        3      3    3      3      4       5    4     3
# Quin        4      4        5      5    4      4      4       5    5     5
# Ryan        5      3        3      3    3      2      4       4    3     4
# Sydney      3      4        3      3    2      3      4       5    5     3
#
# Name     Kelly  Leo  Mia  Noah  Olivia  Parker  Quin  Ryan  Sydney
# Name
# Adam         5    5    5     3       5       4     4     5       3
# Betty        3    5    6     3       5       3     4     3       4
# Charlie      5    4    4     4       5       3     5     3       3
# David        3    4    4     4       5       3     5     3       3
# Eve          3    4    4     3       5       3     4     3       2
# Felix        4    4    5     4       5       3     4     2       3
# Grace        2    5    5     2       4       4     4     4       4
# Harley       5    6    6     6       5       5     5     4       5
# Ian          5    5    6     4       5       4     5     3       5
# Jade         5    6    6     4       4       3     5     4       3
# Kelly        0    6    6     2       3       4     4     4       4
# Leo          6    0    5     5       5       4     4     3       5
# Mia          6    5    0     6       6       4     5     4       5
# Noah         2    5    6     0       4       3     4     4       3
# Olivia       3    5    6     4       0       3     5     4       5
# Parker       4    4    4     3       3       0     4     2       4
# Quin         4    4    5     4       5       4     0     4       4
# Ryan         4    3    4     4       4       2     4     0       4
# Sydney       4    5    5     3       5       4     4     4       0

# %%
def max_pair(distance_matrix):
    player1 = distance_matrix.max().idxmax()
    player2 = distance_matrix.drop(player1).idxmax()[player1]
    
    return(player1, player2)

# %%
def greedy_sort(distance_matrix):
    
    sorted_pairs = []
    
    dm = distance_matrix.copy()
    
    while dm.columns.size > 1:
        a, b = max_pair(dm)

        sorted_pairs.append((a, b))

        dm.drop([a, b], inplace=True, axis='columns')
        dm.drop([a, b], inplace=True, axis='index')
        
    if dm.columns.size > 0:
        sorted_pairs.append(dm.max().idxmax())
        
    return sorted_pairs

# %%
greedy_sort(dm)
# Out:
# [('Adam', 'Harley'),
#  ('Betty', 'Mia'),
#  ('Jade', 'Leo'),
#  ('Charlie', 'Grace'),
#  ('David', 'Ian'),
#  ('Eve', 'Olivia'),
#  ('Felix', 'Kelly'),
#  ('Noah', 'Quin'),
#  ('Parker', 'Sydney'),
#  'Ryan']

# %%
print('\n'.join(str(p) for p in greedy_sort(dm)))
# Out:
# ('Adam', 'Harley')
# ('Betty', 'Mia')
# ('Jade', 'Leo')
# ('Charlie', 'Grace')
# ('David', 'Ian')
# ('Eve', 'Olivia')
# ('Felix', 'Kelly')
# ('Noah', 'Quin')
# ('Parker', 'Sydney')
# Ryan
